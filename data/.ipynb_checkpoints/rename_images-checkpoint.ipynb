# %%
import pandas as pd
import numpy as np
from glob import glob
import os

# %%
img_abs_path = "/home/csikasote/Documents/IciBemba/igc-mu-cibemba/data/image"

# %%
def check_for_unique_images(img_abs_path):
    images_list = glob(f"{img_abs_path}/*.jpg")
    unique_image_list = []     
    for filename in image_list:
        image_id = os.path.basename(images_list[img])
        if '_' in image_id:
            first_part = image_id.split('_')[0]
            print('full_name:',image_id, 'first_part:',first_part)
            #dst =f"{img_abs_path}/{dst}"

# %%
check_for_unique_images(img_abs_path)
# Out:
# Unique Images List: 17519

# %%
a = 'b_c.jpg'
print(a.split('_')[0])
# Out:
# b

# %%
    for img in range(len(images_list)):
        image_id = os.path.basename(images_list[img])
        if image_id not in unique_image_list:
            unique_image_list.append(image_id)
        else:
            pass
    print('Unique Images List:', len(unique_image_list))
